# %% [markdown]
# # Program the surfs the web

# %% [markdown]
# ## Using urllib

# %%
import urllib.request, urllib.parse, urllib.error

# %%
data = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

# %%
# .decode() is used to convert bytes into a string that we can read 
for line in data:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %% [markdown]
# ## Parsing web pages

# %%
# import BeautifulSoup for parsing the web
from bs4 import BeautifulSoup

# %%
# url = 'http://www.dr-chuck.com/page1.htm'

# %%
# parse the web page i guess
# html = urllib.request.urlopen(url).read()
# soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# try other stuff related to beautiful soup
# getting data from a web page
# tags = soup('a')
# for tag in tags:
#     print(tag.get('href', None)) # this is like a dictionary, key yung 'href' then yung value is yung link

# %%
# practice number 2
# site to use for practice: https://en.wikipedia.org/wiki/Snoop_Dogg
# goal here is to get all the links used in this wikipedia page

from bs4 import BeautifulSoup
import ssl

# dealing with SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url_2 = "https://en.wikipedia.org/wiki/Snoop_Dogg"
html_2 = urllib.request.urlopen(url_2, context=ctx).read()
soup_2 = BeautifulSoup(html_2, 'html.parser')

# get the links from the wikipedia page
links = soup_2('a') # for the header to 
for link in links:
    print(link.get('href', None))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Snoop+Dogg
# /w/index.php?title=Special:UserLogin&returnto=Snoop+Dogg
# /w/index.php?title=Special:CreateAccount&returnto=Snoop+Dogg
# /w/index.php?title=Special:UserLogin&returnto=Snoop+Dogg
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life
# #Music_career
# #1991–1997:_Death_Row,_Doggystyle,_and_Tha_Doggfather
# #1998–2006:_Signing_with_No_Limit_and_continued_success
# ...
